# %%
import numpy as np
import pandas as pd
import cv2 as cv
import tensorflow as tf
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import os
from tensorflow.keras.preprocessing import image

# %%
test_input = []
for img_path in glob.glob('data/Haze1k/Haze1k/Haze1k_thin/dataset/test/input/*.png'):
    test_input.append(mpimg.imread(img_path))
    
test_target = []
for img_path in glob.glob('data/Haze1k/Haze1k/Haze1k_thin/dataset/test/target/*.png'):
    test_target.append(mpimg.imread(img_path))

train_input = []
for img_path in glob.glob('data/Haze1k/Haze1k/Haze1k_thin/dataset/train/input/*.png'):
    train_input.append(mpimg.imread(img_path))

train_target = []
for img_path in glob.glob('data/Haze1k/Haze1k/Haze1k_thin/dataset/train/target/*.png'):
    train_target.append(mpimg.imread(img_path))

# %%
plt.imshow(train_input[1])

# %%
plt.imshow(train_target[1])
